# %% [markdown]
# <div style="text-align: justify">
#
# # **Updated population density of the LA city neighborhood councils.**

# %%
import os
import webbrowser
from pyproj import Geod
import geopandas as gpd
import numpy as np
import pandas as pd
import folium

# %%
# Path to the directory.
dir = pwd

# Accessing the Census 2020 data. The geopandas package is used to read the shape 
# file which has the geometry column.
census_2020 = gpd.read_file(
    os.path.join(dir, "tl_2020_06037_tract20/tl_2020_06037_tract20.shp")
)

census_2020 = census_2020[
    ["TRACTCE20", "GEOID20", "INTPTLAT20", "INTPTLON20", "geometry"]
]
census_2020.head()
# Out:
#   TRACTCE20      GEOID20   INTPTLAT20    INTPTLON20  \
# 0    101110  06037101110  +34.2594737  -118.2929869
# 1    101122  06037101122  +34.2677213  -118.2901465
# 2    101220  06037101220  +34.2516083  -118.2816328
# 3    101221  06037101221  +34.2543290  -118.2925767
# 4    101222  06037101222  +34.2513519  -118.2885261
#
#                                             geometry
# 0  POLYGON ((-118.30229 34.25870, -118.30091 34.2...
# 1  POLYGON ((-118.30334 34.27371, -118.30330 34.2...
# 2  POLYGON ((-118.28592 34.25227, -118.28592 34.2...
# 3  POLYGON ((-118.29945 34.25598, -118.29792 34.2...
# 4  POLYGON ((-118.29434 34.25233, -118.29318 34.2...

# %%
# Reading the LA NC shape file.
la_nc = gpd.read_file(
    os.path.join(dir, "neighborhood_councils/neighborhood_councils.shp")
)
la_nc.head()
# Out:
#    OBJECTID                           NAME                        WADDRESS  \
# 0         1                      ARLETA NC        http://www.arletanc.org/
# 1         2                 ARROYO SECO NC             http://www.asnc.us/
# 2         3  ARTS DISTRICT LITTLE TOKYO NC          http://www.hcncla.org/
# 3         4             ATWATER VILLAGE NC  http://www.atwatervillage.org/
# 4         5       BEL AIR-BEVERLY CREST NC              http://babcnc.org/
#
#                       DWEBSITE                DEMAIL        DPHONE  NC_ID  \
# 0     http://empowerla.org/ANC     ANC@EmpowerLA.org  213-978-1551      6
# 1    http://empowerla.org/ASNC    ASNC@EmpowerLA.org  213-978-1551     42
# 2    http://empowerla.org/HCNC    HCNC@EmpowerLA.org  213-978-1551     46
# 3    http://empowerla.org/AVNC    AVNC@EmpowerLA.org  213-978-1551     37
# 4  http://empowerla.org/BABCNC  BABCNC@EmpowerLA.org  213-978-1551     64
#
#     CERTIFIED                        TOOLTIP  \
# 0  2002-10-22                      ARLETA NC
# 1  2002-10-02                 ARROYO SECO NC
# 2  2002-04-27  ARTS DISTRICT LITTLE TOKYO NC
# 3  2003-02-11             ATWATER VILLAGE NC
# 4  2002-10-08       BEL AIR-BEVERLY CREST NC
#
#                                    NLA_URL                    SERVICE_RE  \
# 0   navigatela/reports/nc_reports.cfm?id=6  REGION 1 - NORTH EAST VALLEY
# 1  navigatela/reports/nc_reports.cfm?id=42      REGION 8 - NORTH EAST LA
# 2  navigatela/reports/nc_reports.cfm?id=46          REGION 6 - CENTRAL 2
# 3  navigatela/reports/nc_reports.cfm?id=37               REGION 7 - EAST
# 4  navigatela/reports/nc_reports.cfm?id=64           REGION 11 - WEST LA
#
#                                             geometry
# 0  POLYGON ((-118.44305 34.26328, -118.44303 34.2...
# 1  POLYGON ((-118.19567 34.08613, -118.19568 34.0...
# 2  POLYGON ((-118.23151 34.05348, -118.23141 34.0...
# 3  POLYGON ((-118.25279 34.10833, -118.25292 34.1...
# 4  POLYGON ((-118.36574 34.09948, -118.36575 34.0...

# %%
# ACS demographics data.
acs_demographics = pd.read_csv(os.path.join(dir, "acs_census_tract_la.csv"))

# Cleaning the GEO_ID column to be consistent with the GEOID20 coumn in census_2020 dataframe.
acs_demographics["GEO_ID"] = acs_demographics["GEO_ID"].str.replace("1400000US", "")

# Rename GEO_ID as GEOID20.
acs_demographics = acs_demographics.rename(
    columns={"GEO_ID": "GEOID20", "Total population": "population"}
)
acs_demographics.head()
# Out:
#                                                 NAME  state  county   tract  \
# 0  Census Tract 1997, Los Angeles County, California      6      37  199700
# 1  Census Tract 1998.01, Los Angeles County, Cali...      6      37  199801
# 2  Census Tract 1998.02, Los Angeles County, Cali...      6      37  199802
# 3  Census Tract 1999, Los Angeles County, California      6      37  199900
# 4  Census Tract 2011.10, Los Angeles County, Cali...      6      37  201110
#
#        GEOID20  population
# 0  06037199700        3006
# 1  06037199801        3618
# 2  06037199802        2419
# 3  06037199900        2687
# 4  06037201110        2203

# %%
# Taking a subset of the acs_demographics dataframe.
acs_demographics_subset = acs_demographics[["GEOID20", "population"]]

# Making sure that the crs- coordinate reference system for census_2020 is the same
# as that of the la_nc using the to_crs() method. This will allow the spatial merging
# of both the geopandas dataframes.

census_2020 = census_2020.to_crs(la_nc.crs)

# Spatial overlap of the la_nc and census_2020 data.
census_nc = gpd.overlay(census_2020, la_nc, how="intersection")

census_nc = census_nc[
    ["TRACTCE20", "GEOID20", "NAME", "NC_ID", "INTPTLAT20", "INTPTLON20", "geometry"]
]
print("Number of rows in census_nc: ", census_nc.shape[0])
# Out:
# Number of rows in census_nc:  2108

# %%
# Let us take a look at the spatially merged data:
census_nc.head()
# Out:
#   TRACTCE20      GEOID20                NAME  NC_ID   INTPTLAT20  \
# 0    101110  06037101110  SUNLAND-TUJUNGA NC     10  +34.2594737
# 1    101122  06037101122  SUNLAND-TUJUNGA NC     10  +34.2677213
# 2    101220  06037101220  SUNLAND-TUJUNGA NC     10  +34.2516083
# 3    101221  06037101221  SUNLAND-TUJUNGA NC     10  +34.2543290
# 4    101222  06037101222  SUNLAND-TUJUNGA NC     10  +34.2513519
#
#      INTPTLON20                                           geometry
# 0  -118.2929869  POLYGON ((-118.30229 34.25870, -118.30091 34.2...
# 1  -118.2901465  POLYGON ((-118.30334 34.27371, -118.30330 34.2...
# 2  -118.2816328  POLYGON ((-118.28592 34.25227, -118.28592 34.2...
# 3  -118.2925767  POLYGON ((-118.29945 34.25598, -118.29792 34.2...
# 4  -118.2885261  POLYGON ((-118.29434 34.25233, -118.29318 34.2...

# %%
# Merging the census_nc and acs_demographics_subset.
tracts_nc_demographics = pd.merge(census_nc, acs_demographics_subset, on="GEOID20")
tracts_nc_demographics.shape[0]
# Out:
# 2108

# %% [markdown]
# ### Displaying the duplicate entries- census tracts intersecting more than 1 Neighborhood councils

# %%
df_duplicate = census_nc[census_nc.GEOID20.duplicated(keep=False)]
df_duplicate.sort_values(by=["GEOID20"]).head(15)
# Out:
#    TRACTCE20      GEOID20                         NAME  NC_ID   INTPTLAT20  \
# 1     101122  06037101122           SUNLAND-TUJUNGA NC     10  +34.2677213
# 17    101122  06037101122  FOOTHILL TRAILS DISTRICT NC      9  +34.2677213
# 5     101300  06037101300           SUNLAND-TUJUNGA NC     10  +34.2487777
# 18    101300  06037101300  FOOTHILL TRAILS DISTRICT NC      9  +34.2487777
# 6     101400  06037101400           SUNLAND-TUJUNGA NC     10  +34.2428521
# 19    101400  06037101400  FOOTHILL TRAILS DISTRICT NC      9  +34.2428521
# 42    102103  06037102103           SUN VALLEY AREA NC      8  +34.2250792
# 20    102103  06037102103  FOOTHILL TRAILS DISTRICT NC      9  +34.2250792
# 43    102104  06037102104           SUN VALLEY AREA NC      8  +34.2161873
# 21    102104  06037102104  FOOTHILL TRAILS DISTRICT NC      9  +34.2161873
# 45    102107  06037102107           SUN VALLEY AREA NC      8  +34.2409052
# 22    102107  06037102107  FOOTHILL TRAILS DISTRICT NC      9  +34.2409052
# 23    103101  06037103101  FOOTHILL TRAILS DISTRICT NC      9  +34.2732407
# 7     103101  06037103101           SUNLAND-TUJUNGA NC     10  +34.2732407
# 24    103201  06037103201  FOOTHILL TRAILS DISTRICT NC      9  +34.2656446
#
#       INTPTLON20                                           geometry
# 1   -118.2901465  POLYGON ((-118.30334 34.27371, -118.30330 34.2...
# 17  -118.2901465  POLYGON ((-118.29785 34.27778, -118.29783 34.2...
# 5   -118.2709990  POLYGON ((-118.27822 34.25068, -118.27822 34.2...
# 18  -118.2709990  POLYGON ((-118.26682 34.23124, -118.26695 34.2...
# 6   -118.2941612  POLYGON ((-118.32227 34.24961, -118.32212 34.2...
# 19  -118.2941612  POLYGON ((-118.32238 34.24963, -118.32227 34.2...
# 42  -118.3541880  POLYGON ((-118.36533 34.22870, -118.36396 34.2...
# 20  -118.3541880  POLYGON ((-118.35739 34.22856, -118.35546 34.2...
# 43  -118.3453981  POLYGON ((-118.35620 34.21971, -118.35594 34.2...
# 21  -118.3453981  MULTIPOLYGON (((-118.34413 34.21387, -118.3441...
# 45  -118.3395988  POLYGON ((-118.35739 34.22856, -118.35848 34.2...
# 22  -118.3395988  POLYGON ((-118.36789 34.23939, -118.36788 34.2...
# 23  -118.3078874  POLYGON ((-118.31534 34.27876, -118.31533 34.2...
# 7   -118.3078874  POLYGON ((-118.31760 34.27387, -118.31758 34.2...
# 24  -118.3236267  MULTIPOLYGON (((-118.33294 34.26501, -118.3329...

# %% [markdown]
# ### So here is a method to take care of cases where the census tract intersects more than 1 NCs.
#
# - Find the area for each entry in census dataframe.
# - Group the census dataframe by 'TRACTCE20' and then find sum of the area- this gives you the total area of each census tract.
# - Next, find the percentage of area of the census tract intersecting different NCs.
# - Use this information to find the percentage of population for each census tract.
# - Then find the total population by grouping them by NCs.

# %% [markdown]
# ### Defining a [function](https://github.com/hackforla/access-the-data-workshop-311-analysis/blob/main/notebooks/NC-population-density.ipynb) to compute the area in square miles (area (sq_miles)).

# %%
geod = Geod(ellps="WGS84")


def area_sq_miles(geo):
    """ Returns area in square miles for the input geo, where geo is the polygon 
    (boundary feature) for each NC given by the geometry column.
    """
    area_sq_meters = abs(geod.geometry_area_perimeter(geo)[0])
    return area_sq_meters * 3.86102e-7

# %%
# Add the area column.
tracts_nc_demographics = pd.merge(census_nc, acs_demographics_subset, on="GEOID20")
tracts_nc_demographics["area"] = tracts_nc_demographics.apply(
    lambda row: area_sq_miles(row.geometry), axis=1
)
tracts_nc_demographics.head(10)
# Out:
#   TRACTCE20      GEOID20                         NAME  NC_ID   INTPTLAT20  \
# 0    101110  06037101110           SUNLAND-TUJUNGA NC     10  +34.2594737
# 1    101122  06037101122           SUNLAND-TUJUNGA NC     10  +34.2677213
# 2    101122  06037101122  FOOTHILL TRAILS DISTRICT NC      9  +34.2677213
# 3    101220  06037101220           SUNLAND-TUJUNGA NC     10  +34.2516083
# 4    101221  06037101221           SUNLAND-TUJUNGA NC     10  +34.2543290
# 5    101222  06037101222           SUNLAND-TUJUNGA NC     10  +34.2513519
# 6    101300  06037101300           SUNLAND-TUJUNGA NC     10  +34.2487777
# 7    101300  06037101300  FOOTHILL TRAILS DISTRICT NC      9  +34.2487777
# 8    101400  06037101400           SUNLAND-TUJUNGA NC     10  +34.2428521
# 9    101400  06037101400  FOOTHILL TRAILS DISTRICT NC      9  +34.2428521
#
#      INTPTLON20                                           geometry  \
# 0  -118.2929869  POLYGON ((-118.30229 34.25870, -118.30091 34.2...
# 1  -118.2901465  POLYGON ((-118.30334 34.27371, -118.30330 34.2...
# 2  -118.2901465  POLYGON ((-118.29785 34.27778, -118.29783 34.2...
# 3  -118.2816328  POLYGON ((-118.28592 34.25227, -118.28592 34.2...
# 4  -118.2925767  POLYGON ((-118.29945 34.25598, -118.29792 34.2...
# 5  -118.2885261  POLYGON ((-118.29434 34.25233, -118.29318 34.2...
# 6  -118.2709990  POLYGON ((-118.27822 34.25068, -118.27822 34.2...
# 7  -118.2709990  POLYGON ((-118.26682 34.23124, -118.26695 34.2...
# 8  -118.2941612  POLYGON ((-118.32227 34.24961, -118.32212 34.2...
# 9  -118.2941612  POLYGON ((-118.32238 34.24963, -118.32227 34.2...
#
#    population      area
# 0        3923  0.441083
# 1        4119  1.020872
# 2        4119  0.000038
# 3        3775  0.269841
# 4        3787  0.136748
# 5        2717  0.114484
# 6        3741  0.993003
# 7        3741  0.002387
# 8        3246  2.414663
# 9        3246  0.021664

# %%
tracts_nc_test = tracts_nc_demographics.groupby("TRACTCE20", as_index=False).agg(
    {
        "NC_ID": "first",
        "NAME": "first",
        "geometry": "first",
        "INTPTLAT20": "first",
        "INTPTLON20": "first",
        "NAME": "first",
        "GEOID20": "first",
        "area": sum,
    }
)
tracts_nc_test.rename(columns={"area": "total_area"}, inplace=True)
tracts_nc_test = tracts_nc_test[["TRACTCE20", "total_area"]]

# %%
# Let us merge the tracts_nc_demographics and tracts_nc_test dataframes.
tracts_nc_perc = pd.merge(tracts_nc_demographics, tracts_nc_test, on="TRACTCE20")
tracts_nc_perc.head(10)
# Out:
#   TRACTCE20      GEOID20                         NAME  NC_ID   INTPTLAT20  \
# 0    101110  06037101110           SUNLAND-TUJUNGA NC     10  +34.2594737
# 1    101122  06037101122           SUNLAND-TUJUNGA NC     10  +34.2677213
# 2    101122  06037101122  FOOTHILL TRAILS DISTRICT NC      9  +34.2677213
# 3    101220  06037101220           SUNLAND-TUJUNGA NC     10  +34.2516083
# 4    101221  06037101221           SUNLAND-TUJUNGA NC     10  +34.2543290
# 5    101222  06037101222           SUNLAND-TUJUNGA NC     10  +34.2513519
# 6    101300  06037101300           SUNLAND-TUJUNGA NC     10  +34.2487777
# 7    101300  06037101300  FOOTHILL TRAILS DISTRICT NC      9  +34.2487777
# 8    101400  06037101400           SUNLAND-TUJUNGA NC     10  +34.2428521
# 9    101400  06037101400  FOOTHILL TRAILS DISTRICT NC      9  +34.2428521
#
#      INTPTLON20                                           geometry  \
# 0  -118.2929869  POLYGON ((-118.30229 34.25870, -118.30091 34.2...
# 1  -118.2901465  POLYGON ((-118.30334 34.27371, -118.30330 34.2...
# 2  -118.2901465  POLYGON ((-118.29785 34.27778, -118.29783 34.2...
# 3  -118.2816328  POLYGON ((-118.28592 34.25227, -118.28592 34.2...
# 4  -118.2925767  POLYGON ((-118.29945 34.25598, -118.29792 34.2...
# 5  -118.2885261  POLYGON ((-118.29434 34.25233, -118.29318 34.2...
# 6  -118.2709990  POLYGON ((-118.27822 34.25068, -118.27822 34.2...
# 7  -118.2709990  POLYGON ((-118.26682 34.23124, -118.26695 34.2...
# 8  -118.2941612  POLYGON ((-118.32227 34.24961, -118.32212 34.2...
# 9  -118.2941612  POLYGON ((-118.32238 34.24963, -118.32227 34.2...
#
#    population      area  total_area
# 0        3923  0.441083    0.441083
# 1        4119  1.020872    1.020910
# 2        4119  0.000038    1.020910
# 3        3775  0.269841    0.269841
# 4        3787  0.136748    0.136748
# 5        2717  0.114484    0.114484
# 6        3741  0.993003    0.995390
# 7        3741  0.002387    0.995390
# 8        3246  2.414663    2.436327
# 9        3246  0.021664    2.436327

# %%
# Evaluating the percentage of the intersecting areas (area_perc):
tracts_nc_perc["area_perc"] = tracts_nc_perc["area"] / tracts_nc_perc["total_area"]

# Adding the percentage of population column
tracts_nc_perc["total_population"] = (
    tracts_nc_perc["population"] * tracts_nc_perc["area_perc"]
)

# Rounding the population number:
tracts_nc_perc["total_population"] = tracts_nc_perc["total_population"].apply(np.floor)

# Converting the population to integer type.
tracts_nc_perc["total_population"] = tracts_nc_perc["total_population"].astype(int)

tracts_nc_perc.head(10)
# Out:
#   TRACTCE20      GEOID20                         NAME  NC_ID   INTPTLAT20  \
# 0    101110  06037101110           SUNLAND-TUJUNGA NC     10  +34.2594737
# 1    101122  06037101122           SUNLAND-TUJUNGA NC     10  +34.2677213
# 2    101122  06037101122  FOOTHILL TRAILS DISTRICT NC      9  +34.2677213
# 3    101220  06037101220           SUNLAND-TUJUNGA NC     10  +34.2516083
# 4    101221  06037101221           SUNLAND-TUJUNGA NC     10  +34.2543290
# 5    101222  06037101222           SUNLAND-TUJUNGA NC     10  +34.2513519
# 6    101300  06037101300           SUNLAND-TUJUNGA NC     10  +34.2487777
# 7    101300  06037101300  FOOTHILL TRAILS DISTRICT NC      9  +34.2487777
# 8    101400  06037101400           SUNLAND-TUJUNGA NC     10  +34.2428521
# 9    101400  06037101400  FOOTHILL TRAILS DISTRICT NC      9  +34.2428521
#
#      INTPTLON20                                           geometry  \
# 0  -118.2929869  POLYGON ((-118.30229 34.25870, -118.30091 34.2...
# 1  -118.2901465  POLYGON ((-118.30334 34.27371, -118.30330 34.2...
# 2  -118.2901465  POLYGON ((-118.29785 34.27778, -118.29783 34.2...
# 3  -118.2816328  POLYGON ((-118.28592 34.25227, -118.28592 34.2...
# 4  -118.2925767  POLYGON ((-118.29945 34.25598, -118.29792 34.2...
# 5  -118.2885261  POLYGON ((-118.29434 34.25233, -118.29318 34.2...
# 6  -118.2709990  POLYGON ((-118.27822 34.25068, -118.27822 34.2...
# 7  -118.2709990  POLYGON ((-118.26682 34.23124, -118.26695 34.2...
# 8  -118.2941612  POLYGON ((-118.32227 34.24961, -118.32212 34.2...
# 9  -118.2941612  POLYGON ((-118.32238 34.24963, -118.32227 34.2...
#
#    population      area  total_area  area_perc  total_population
# 0        3923  0.441083    0.441083   1.000000              3923
# 1        4119  1.020872    1.020910   0.999963              4118
# 2        4119  0.000038    1.020910   0.000037                 0
# 3        3775  0.269841    0.269841   1.000000              3775
# 4        3787  0.136748    0.136748   1.000000              3787
# 5        2717  0.114484    0.114484   1.000000              2717
# 6        3741  0.993003    0.995390   0.997602              3732
# 7        3741  0.002387    0.995390   0.002398                 8
# 8        3246  2.414663    2.436327   0.991108              3217
# 9        3246  0.021664    2.436327   0.008892                28

# %%
# Summming up the population of each NCs.
tracts_nc_pop = tracts_nc_perc.groupby("NAME", as_index=False).agg(
    {"NC_ID": "first", "NAME": "first", "total_population": sum}
)
tracts_nc_pop.head(50)
# Out:
#     NC_ID                                               NAME  total_population
# 0       6                                          ARLETA NC             37542
# 1      42                                     ARROYO SECO NC             20626
# 2      46                      ARTS DISTRICT LITTLE TOKYO NC              5692
# 3      37                                 ATWATER VILLAGE NC             29731
# 4      64                           BEL AIR-BEVERLY CREST NC             40587
# 5      50                                   BOYLE HEIGHTS NC            102445
# 6      13                                     CANOGA PARK NC             55021
# 7     110                                 CENTRAL ALAMEDA NC             44111
# 8      32                               CENTRAL HOLLYWOOD NC             24865
# 9      95                               CENTRAL SAN PEDRO NC             30353
# 10     99                                      CHATSWORTH NC             44426
# 11     96                               COASTAL SAN PEDRO NC             37560
# 12     86  COMMUNITY AND NEIGHBORS FOR NINTH DISTRICT UNI...             57321
# 13     70                                         DEL REY NC             54842
# 14     52                               DOWNTOWN LOS ANGELES             53027
# 15     40                                      EAGLE ROCK NC             49006
# 16     34                                  EAST HOLLYWOOD NC             43736
# 17     44                                       ECHO PARK NC             44828
# 18     43                        ELYSIAN VALLEY RIVERSIDE NC              7347
# 19     81               EMPOWERMENT CONGRESS CENTRAL AREA NC             52536
# 20     77                 EMPOWERMENT CONGRESS NORTH AREA NC             79106
# 21     87            EMPOWERMENT CONGRESS SOUTHEAST AREA NDC            102907
# 22     84            EMPOWERMENT CONGRESS SOUTHWEST AREA NDC             57645
# 23     79                 EMPOWERMENT CONGRESS WEST AREA NDC             43862
# 24     18                                          ENCINO NC             56640
# 25      9                        FOOTHILL TRAILS DISTRICT NC             27168
# 26     39                                   GLASSELL PARK NC             35611
# 27      4                             GRANADA HILLS NORTH NC             33715
# 28    118                             GRANADA HILLS SOUTH NC             38780
# 29    102                            GREATER CYPRESS PARK NC             12965
# 30     28                             GREATER TOLUCA LAKE NC             21593
# 31     21                                GREATER VALLEY GLEN             45841
# 32    119                                GREATER WILSHIRE NC             47793
# 33     92                                     HARBOR CITY NC             43522
# 34     90                            HARBOR GATEWAY NORTH NC             69147
# 35     91                            HARBOR GATEWAY SOUTH NC             66146
# 36    126                                          HERMON NC              4805
# 37    128                         HISTORIC CULTURAL NORTH NC             26324
# 38     41                          HISTORIC HIGHLAND PARK NC             63053
# 39     29                            HOLLYWOOD HILLS WEST NC             41457
# 40     33                       HOLLYWOOD STUDIO DISTRICT NC             26313
# 41     30                                HOLLYWOOD UNITED NC             26838
# 42     48                                           LA-32 NC             66207
# 43     19                                     LAKE BALBOA NC             44967
# 44     47                                 LINCOLN HEIGHTS NC             32032
# 45     36                                       LOS FELIZ NC             37979
# 46     54                                  MACARTHUR PARK NC             27513
# 47     67                                       MAR VISTA NC             56422
# 48     73                                        MID CITY NC             28582
# 49     58                                   MID CITY WEST CC             88723

# %%
tracts_nc_pop.total_population.sum()
# Out:
# 4534011

# %% [markdown]
# ### Now that we have the population of each NC, let us move on to getting the area and finally the updated population density of the neighborhood councils.

# %%
# Grouping the original tracts_nc_demographics dataframe by NAME and then summing
# up the total area- this gives the area of each neighborhood # council. Very
# important note here- groupby function works when trying to aggregate dataframes
# but for spatial data, we can aggregate the geometry features using dissolve function.

tracts_nc_area = tracts_nc_demographics.dissolve(
    by="NAME", as_index=False, aggfunc=({"NC_ID": "first", "area": sum})
)

# Gathering all the columns of interest.
tracts_nc_final = tracts_nc_area.join(tracts_nc_pop["total_population"])
tracts_nc_final["pop_density"] = (
    tracts_nc_final["total_population"] / tracts_nc_final["area"]
)

# Rearranging the columns.
tracts_nc_final = tracts_nc_final[
    ["NAME", "geometry", "NC_ID", "total_population", "area", "pop_density"]
]
tracts_nc_final.head(15)
# Out:
#                                                  NAME  \
# 0                                           ARLETA NC
# 1                                      ARROYO SECO NC
# 2                       ARTS DISTRICT LITTLE TOKYO NC
# 3                                  ATWATER VILLAGE NC
# 4                            BEL AIR-BEVERLY CREST NC
# 5                                    BOYLE HEIGHTS NC
# 6                                      CANOGA PARK NC
# 7                                  CENTRAL ALAMEDA NC
# 8                                CENTRAL HOLLYWOOD NC
# 9                                CENTRAL SAN PEDRO NC
# 10                                      CHATSWORTH NC
# 11                               COASTAL SAN PEDRO NC
# 12  COMMUNITY AND NEIGHBORS FOR NINTH DISTRICT UNI...
# 13                                         DEL REY NC
# 14                               DOWNTOWN LOS ANGELES
#
#                                              geometry  NC_ID  \
# 0   POLYGON ((-118.41010 34.23309, -118.41034 34.2...      6
# 1   POLYGON ((-118.18576 34.09293, -118.18576 34.0...     42
# 2   POLYGON ((-118.22877 34.04155, -118.22827 34.0...     46
# 3   POLYGON ((-118.25399 34.10816, -118.25424 34.1...     37
# 4   POLYGON ((-118.46573 34.07325, -118.46581 34.0...     64
# 5   POLYGON ((-118.20504 34.01263, -118.20504 34.0...     50
# 6   POLYGON ((-118.58846 34.19524, -118.58846 34.1...     13
# 7   POLYGON ((-118.23777 33.98933, -118.23777 33.9...    110
# 8   POLYGON ((-118.32445 34.08712, -118.32445 34.0...     32
# 9   POLYGON ((-118.28794 33.73151, -118.28795 33.7...     95
# 10  POLYGON ((-118.56231 34.23405, -118.56232 34.2...     99
# 11  POLYGON ((-118.26232 33.70500, -118.26232 33.7...     96
# 12  POLYGON ((-118.25640 33.96470, -118.25640 33.9...     86
# 13  POLYGON ((-118.43312 33.97609, -118.43315 33.9...     70
# 14  POLYGON ((-118.22419 34.01494, -118.22569 34.0...     52
#
#     total_population       area   pop_density
# 0              37542   3.284868  11428.769873
# 1              20626   3.063327   6733.202882
# 2               5692   0.879216   6473.953059
# 3              29731   8.748450   3398.430652
# 4              40587  17.038756   2382.040126
# 5             102445   5.735881  17860.379013
# 6              55021   3.689892  14911.276687
# 7              44111   1.358014  32481.989849
# 8              24865   1.229127  20229.813381
# 9              30353   2.438025  12449.833858
# 10             44426  11.394106   3899.033491
# 11             37560   4.713196   7969.115432
# 12             57321   2.550243  22476.679335
# 13             54842   3.027096  18117.030631
# 14             53027   5.030842  10540.383485

# %% [markdown]
# ### I am going to go ahead and plot the tracts_nc_final using geopandas explore- folium.

# %%
m = tracts_nc_final.explore(
    column="NAME",  # Make choropleth based on 'NC name' column.
    name="NC Regions",
    tooltip="NAME",  # Show 'NC name' value in tooltip (on hover).
    color="red",  # Use red color on all points.
    popup=True,  # Show all values in popup (on click).
    tiles="openstreetmap",  # Use "openstreetmap" tiles.
    cmap="Set1",  # Use "Set1" matplotlib colormap.
    style_kwds=dict(color="black"),  # Use black outline.
    legend=False,
)
folium.TileLayer("Stamen Terrain").add_to(m)
folium.TileLayer("Stamen Toner").add_to(m)
folium.TileLayer("Stamen Water Color").add_to(m)
folium.TileLayer("cartodbpositron").add_to(m)
folium.TileLayer("cartodbdark_matter").add_to(m)
folium.LayerControl().add_to(m)
m.save("tracts_nc_final1.html")
webbrowser.open("tracts_nc_final1.html")
# Out:
# True

# %%
tracts_nc_final.total_population.sum()
# Out:
# 4534011

# %% [markdown]
# ### According to the [Census Bureau](https://www.census.gov/quickfacts/losangelescitycalifornia?), the total population estimate of LA city councils using the census 2020 data is: 3,849,297.
#
# ### The sum of the population of all NCs at the tract level is inflated. I am going to explore this and add some filters - area and population to account for this inflated value.
